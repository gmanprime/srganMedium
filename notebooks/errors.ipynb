# %% [markdown]
# In this notebook, I check out all the errors that are present in the raw datasets

# %%
import xarray as xr
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import matplotlib as mpl
# import cartopy.crs as ccrs  # for plotting map
# from sklearn.preprocessing import MinMaxScaler

# %%
PATH = '../Data/raw_data/'
pwat_p01 = xr.open_dataset(PATH + 'GEFSv12-Reforecast_pwat_p01_error.nc')

# %%
print(pwat_p01.pwat.values.max()) # max value for pwat p01 is 99998.984, which is obviously wrong

# np.where(pwat_p01.pwat.values == np.max(pwat_p01.pwat.values)) index 27914
# Out:
# 29.64391

# %%
pwat_p01.pwat[27914].values # ??????????
# I shall take 27914 to be mean of 27913 and 27915
# Although this index lies in the testing dataset,
# I still proceed to replace it because the value does not make sense.
# In actual real time data, it will be replaced anyway.
# There is no data leakage whatsoever, as the values that replaced 27914
# belongs to test dataset itself.
# Out:
# array([[1.4000015 , 1.5499992 , 1.6000023 , 1.4500046 , 1.5999985 ,
#         1.9500008 , 1.6500015 , 1.1500015 , 1.4000015 , 1.9000015 ,
#         1.9500008 , 1.7000008 , 1.2000008 , 0.75      , 0.45000458,
#         0.29999924, 0.19999695, 0.29999924, 0.40000153],
#        [0.9000015 , 1.        , 1.        , 0.6499977 , 0.95000076,
#         1.7999992 , 2.1500015 , 1.5499992 , 1.25      , 1.5       ,
#         1.5499992 , 1.5       , 1.3999977 , 1.0499992 , 0.94999695,
#         0.9000015 , 0.75      , 0.54999924, 0.3500023 ],
#        [1.25      , 1.0499954 , 0.5999985 , 0.10000229, 0.        ,
#         1.2000008 , 2.050003  , 1.9000015 , 1.3499985 , 1.25      ,
#         1.3499985 , 1.3499985 , 1.3499985 , 1.25      , 1.1500015 ,
#         1.1500015 , 1.        , 0.80000305, 0.3999977 ],
#        [1.7999992 , 0.79999924, 0.34999847, 1.4500008 , 1.2000008 ,
#         0.25      , 1.5000038 , 1.5499992 , 1.2000008 , 1.2999992 ,
#         1.25      , 1.3500023 , 1.25      , 1.2499962 , 1.2999992 ,
#         1.4000015 , 1.25      , 1.1500015 , 0.8999977 ],
#        [2.3999977 , 1.2999992 , 0.24999619, 2.2000046 , 2.449997  ,
#         1.2999992 , 0.20000076, 0.54999924, 0.34999847, 0.79999924,
#         1.050003  , 1.199997  , 1.25      , 1.1000023 , 1.        ,
#         1.1499977 , 1.1000023 , 1.0999985 , 0.9000015 ],
#        [2.5       , 1.8500023 , 0.6500015 , 1.199997  , 2.7000008 ,
#         2.550003  , 1.3999977 , 0.95000076, 1.        , 0.6000023 ,
#         0.10000229, 0.40000153, 0.5999985 , 1.        , 1.1500015 ,
#         0.95000076, 0.8500023 , 0.79999924, 0.6500015 ],
#        [0.10000229, 0.5       , 0.75      , 0.14999771, 0.8500023 ,
#         2.1000023 , 2.5       , 2.25      , 2.1000023 , 1.8500023 ,
#         1.5999985 , 1.0499992 , 0.4999962 , 0.29999924, 1.0999985 ,
#         1.1000023 , 0.95000076, 0.45000076, 0.10000229],
#        [4.2999954 , 2.3499985 , 0.25      , 0.6000023 , 0.5999985 ,
#         0.29999924, 1.5       , 2.25      , 2.2000008 , 1.9000015 ,
#         1.9500008 , 1.7499962 , 1.3499985 , 0.75      , 0.        ,
#         1.        , 1.2499962 , 0.79999924, 0.20000076],
#        [5.8999977 , 4.1000023 , 1.9500008 , 0.25      , 0.54999924,
#         0.5999985 , 0.05000305, 0.8500023 , 1.9500008 , 1.949997  ,
#         1.8499985 , 1.9000015 , 1.8999977 , 1.449997  , 0.69999695,
#         0.29999924, 1.0999985 , 1.1499977 , 0.30000305],
#        [3.3999977 , 3.4000015 , 2.8500023 , 2.        , 0.29999924,
#         0.9000015 , 1.0499992 , 0.6000023 , 0.8499985 , 1.9000015 ,
#         1.9500008 , 1.8999977 , 2.        , 1.7000046 , 0.95000076,
#         0.20000076, 0.79999924, 0.95000076, 0.45000076],
#        [0.8999977 , 1.5       , 2.1000023 , 2.5999985 , 1.5499992 ,
#         0.        , 0.79999924, 1.4500008 , 0.6499977 , 0.75      ,
#         1.050003  , 1.        , 1.5       , 1.3499985 , 1.1000023 ,
#         0.40000153, 0.04999924, 0.30000305, 0.5       ],
#        [0.        , 0.45000076, 1.        , 2.2000008 , 2.1499977 ,
#         0.79999924, 0.09999847, 0.9000015 , 1.0999985 , 0.5       ,
#         0.40000153, 0.10000229, 1.        , 1.2499962 , 1.0499992 ,
#         0.69999695, 0.55000305, 0.45000076, 0.15000153],
#        [0.8499985 , 0.10000229, 0.5       , 1.6499977 , 1.9000015 ,
#         1.0999985 , 0.25      , 0.54999924, 1.2999992 , 1.8500023 ,
#         1.3999977 , 0.20000076, 0.8500023 , 1.2999992 , 1.199997  ,
#         1.0499992 , 1.2000008 , 0.8499985 , 0.15000153],
#        [0.6500015 , 0.19999695, 0.04999924, 1.1000023 , 1.4999962 ,
#         1.0499992 , 0.34999847, 0.14999771, 0.8499985 , 1.6500015 ,
#         1.5999985 , 0.30000305, 0.6500015 , 0.8999977 , 1.1500015 ,
#         1.2000008 , 1.550003  , 1.25      , 0.54999924],
#        [0.40000153, 0.45000076, 0.55000305, 1.25      , 1.        ,
#         0.5       , 0.09999847, 0.        , 0.14999771, 0.94999695,
#         1.2999992 , 0.54999924, 0.54999924, 0.4999962 , 0.5       ,
#         0.6500015 , 1.25      , 1.199997  , 0.75      ],
#        [0.04999542, 0.79999924, 0.9999962 , 0.8499985 , 0.30000305,
#         1.6000023 , 1.7000008 , 0.6000023 , 0.04999924, 0.5       ,
#         0.8500023 , 0.5       , 0.29999924, 0.29999924, 0.04999924,
#         0.14999771, 0.29999924, 0.5       , 0.45000076]], dtype=float32)

# %%
pwat_p01.pwat[27914] = 0.5*(pwat_p01.pwat[27913].values + pwat_p01.pwat[27915].values)

# %%
pwat_p01.pwat[27913]
# Out:
# <xarray.DataArray 'pwat' (latitude: 16, longitude: 19)> Size: 1kB
# array([[2.48381 , 3.48381 , 3.683811, ..., 0.383812, 0.083809, 0.21619 ],
#        [3.383808, 4.28381 , 4.883812, ..., 0.78381 , 0.583809, 0.383808],
#        [2.583813, 3.583813, 4.683811, ..., 0.683811, 0.48381 , 0.683811],
#        ...,
#        [1.883808, 1.78381 , 1.48381 , ..., 0.683811, 0.883812, 0.48381 ],
#        [1.783813, 1.48381 , 1.183811, ..., 0.48381 , 0.583809, 0.28381 ],
#        [0.083809, 0.183807, 0.78381 , ..., 0.183811, 0.183811, 0.183807]],
#       dtype=float32)
# Coordinates:
#     time       datetime64[ns] 8B 2019-02-09T12:00:00
#   * longitude  (longitude) float64 152B 101.5 101.8 102.0 ... 105.5 105.8 106.0
#   * latitude   (latitude) float64 128B 3.5 3.25 3.0 2.75 ... 0.5 0.25 0.0 -0.25
# Attributes: (12/30)
#     standard_name:                            unknown
#     long_name:                                Precipitable water
#     units:                                    kg m**-2
#     GRIB_paramId:                             3054
#     GRIB_dataType:                            pf
#     GRIB_numberOfPoints:                      1038240
#     ...                                       ...
#     GRIB_longitudeOfLastGridPointInDegrees:   359.75
#     GRIB_missingValue:                        9999
#     GRIB_name:                                Precipitable water
#     GRIB_shortName:                           pwat
#     GRIB_totalNumber:                         10
#     GRIB_units:                               kg m**-2

# %%
pwat_p01.pwat.values.max()
# Out:
# np.float32(29.64391)

# %%
# lat = 0.75
# lon = 105
# pwat_p01.groupby(pwat_p01.time.dt.month).mean().pwat.sel(latitude=lat, longitude=lon).plot(alpha=0.5)
pathwrf = '../Data/Transitions/3. error_correction/'
pwat_p01.to_netcdf(pathwrf+'GEFSv12-Reforecast_pwat_p01.nc')
